# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Generate synthetic data
np.random.seed(0)
X = np.random.rand(1000, 10)  # Features
y = np.random.randint(2, size=(1000,))  # Binary labels

# Define the neural network model
model = Sequential([
    Dense(64, activation='relu', input_shape=(10,)),
    Dropout(0.2),  # Dropout layer for regularization
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 64)                704
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 1)                 33
#
# ...
# Total params: 2817 (11.00 KB)
# Trainable params: 2817 (11.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X, y, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 1s 11ms/step - loss: 0.7109 - accuracy: 0.4888 - val_loss: 0.6935 - val_accuracy: 0.5400
# Epoch 2/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6964 - accuracy: 0.5075 - val_loss: 0.6947 - val_accuracy: 0.4950
# Epoch 3/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6934 - accuracy: 0.5013 - val_loss: 0.6937 - val_accuracy: 0.5150
# Epoch 4/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6922 - accuracy: 0.5175 - val_loss: 0.6961 - val_accuracy: 0.4850
# Epoch 5/20
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6919 - accuracy: 0.5250 - val_loss: 0.6984 - val_accuracy: 0.4700
# Epoch 6/20
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.5375 - val_loss: 0.6955 - val_accuracy: 0.5050
# Epoch 7/20
# ...

# %% [markdown]
# We generate synthetic data with 1000 samples and 10 features per sample.
#
# The labels y are binary, randomly generated integers (0 or 1).
#
# We define a sequential neural network model using Keras.
#
# The model consists of three fully connected (dense) layers with ReLU activation functions.
#
# We include dropout layers after the first two hidden layers to introduce regularization and prevent overfitting.
#
# The input shape of the first layer is (10,), corresponding to the ten features in our dataset.
#
# The output layer has a single neuron with a sigmoid activation function, suitable for binary classification tasks.
#
# We compile the model using the Adam optimizer and binary cross-entropy loss, which is commonly used for binary classification problems.
#
# We train the model on the synthetic dataset (X and y) for 20 epochs with a batch size of 32.
#
# The validation_split=0.2 argument specifies that 20% of the training data will be used for validation during training.
